# %% [markdown]
# # 9장 건강 관련 데이터 분석

# %% [markdown]
# ## 9.2 데이터 가공

# %% [markdown]
# ### (1) 데이터 읽어와서 확인하기

# %%
from pandas import *

happy_life = read_excel('https://raw.githubusercontent.com/aidalabs/Lectures/master/LectureFiles/dataset/Korea_Happiness_Map-Life_Satisfaction.xlsx')
happy_life.head()
# Out:
#    No     시도   구군  삶의 만족도
# 0   1  서울특별시  종로구  0.4437
# 1   2  서울특별시   중구  0.4976
# 2   3  서울특별시  용산구  0.6161
# 3   4  서울특별시  성동구  0.4729
# 4   5  서울특별시  광진구  0.4041

# %%
happy_health = read_excel('https://raw.githubusercontent.com/aidalabs/Lectures/master/LectureFiles/dataset/Korea_Happiness_Map-Health.xlsx')
happy_health.head()
# Out:
#    No     시도   구군      평균  주관적 건강수준 인지율  인구 십만명당 정신건강증진기관 수  \
# 0   1  서울특별시  종로구  0.9220        0.8424              0.6914
# 1   2  서울특별시   중구  0.6742        0.5772              0.4106
# 2   3  서울특별시  용산구  0.5898        0.9819              0.3353
# 3   4  서울특별시  성동구  0.4794        0.5465              0.3321
# 4   5  서울특별시  광진구  0.6373        0.8534              0.7393
#
#    인구 천명당 의료기관 종사 의사수  건강생활실천율  인구 천명당 의료기관병상수
# 0              1.0000   0.9697          0.7616
# 1              0.9995   0.9669          0.4043
# 2              0.6046   0.9844          0.1433
# 3              0.5783   0.9776          0.2111
# 4              0.6352   0.8022          0.1936

# %%
happy_safe = read_excel('https://raw.githubusercontent.com/aidalabs/Lectures/master/LectureFiles/dataset/Korea_Happiness_Map-Safety.xlsx')
happy_safe.head()
# Out:
#    No     시도   구군      평균  사회안전에 대한 인식 b)  인구 천명당 cctv 대수 b)  \
# 0   1  서울특별시  종로구  0.7470          0.9965             0.4796
# 1   2  서울특별시   중구  0.9320          0.9707             0.8214
# 2   3  서울특별시  용산구  0.5537          0.6641             0.4311
# 3   4  서울특별시  성동구  0.5347          0.7452             0.4330
# 4   5  서울특별시  광진구  0.6072          0.7179             0.2196
#
#    인구 십만명당 응급의료기관 및 응급실 운영기관수  단위면적당 지역경찰관서 수  지역안전등급 현황 중 '교통사고 및 화재' a)
# 0                      0.7498          0.9998                      0.0162
# 1                      0.6938          1.0000                      0.3014
# 2                      0.1768          0.8923                      0.5075
# 3                      0.1562          0.9800                      0.3014
# 4                      0.2019          0.9785                      0.7117

# %%
happy_environ = read_excel('https://raw.githubusercontent.com/aidalabs/Lectures/master/LectureFiles/dataset/Korea_Happiness_Map-Environment.xlsx')
happy_environ.head()
# Out:
#    No     시도   구군      평균  환경체감도 b)  인구 천명당 1일 산업폐수 방류량 a)  도시지역 중 '녹지지역 비율'  \
# 0   1  서울특별시  종로구  0.4637    0.4658                 0.7223            0.2012
# 1   2  서울특별시   중구  0.2865    0.1077                 0.6957            0.0013
# 2   3  서울특별시  용산구  0.5030    0.3142                 0.7185            0.1349
# 3   4  서울특별시  성동구  0.4196    0.1480                 0.6868            0.0347
# 4   5  서울특별시  광진구  0.4992    0.1229                 0.6940            0.0574
#
#    미세먼지(PM2.5) a) b)  주민 1인당 생활폐기물배출량 a)
# 0             0.7704              0.0006
# 1             0.6617              0.0000
# 2             0.6895              0.4571
# 3             0.3757              0.7426
# 4             0.7235              0.7016

# %%
happy_econo = read_excel('https://raw.githubusercontent.com/aidalabs/Lectures/master/LectureFiles/dataset/Korea_Happiness_Map-Economy.xlsx')
happy_econo.head()
# Out:
#    No     시도   구군      평균  1인당 지역내총생산(GRDP)  인구 천명당 사업체수  인구 천명당 종사자수  \
# 0   1  서울특별시  종로구  1.0000            1.0000       1.0000       1.0000
# 1   2  서울특별시   중구  0.9806            1.0000       1.0000       1.0000
# 2   3  서울특별시  용산구  0.6915            0.6334       0.5493       0.7282
# 3   4  서울특별시  성동구  0.6533            0.5132       0.5368       0.6849
# 4   5  서울특별시  광진구  0.4445            0.2906       0.3424       0.3870
#
#    국민기초생활보장 수급자비율 a)  종사자 천명당 영세자영업자 수 a)
# 0             0.7564               0.9037
# 1             0.6718               0.9177
# 2             0.7910               0.8341
# 3             0.8243               0.8377
# 4             0.8681               0.7480

# %%
happy_edu = read_excel('https://raw.githubusercontent.com/aidalabs/Lectures/master/LectureFiles/dataset/Korea_Happiness_Map-Education.xlsx')
happy_edu.head()
# Out:
#    No     시도   구군      평균  교원 1인당 학생수  영유아 천명당 보육시설 수  인구 십만명당 학교수  \
# 0   1  서울특별시  종로구  0.6839      0.8505          0.6248       0.2249
# 1   2  서울특별시   중구  0.5013      0.8729          0.4147       0.2294
# 2   3  서울특별시  용산구  0.2679      0.6479          0.3804       0.1281
# 3   4  서울특별시  성동구  0.2464      0.7661          0.2270       0.1308
# 4   5  서울특별시  광진구  0.4879      0.9309          0.4263       0.1278
#
#    인구 천명당 사설학원수
# 0        0.8126
# 1        0.2944
# 2        0.1629
# 3        0.3366
# 4        0.4607

# %%
happy_relation = read_excel('https://raw.githubusercontent.com/aidalabs/Lectures/master/LectureFiles/dataset/Korea_Happiness_Map-Relationships_and_Social_Participation.xlsx')
happy_relation.head()
# Out:
#    No     시도   구군      평균  인구 십만명당 자살률 a)  1인가구(독거노인 제외) 비율 a)  독거노인가구 비율 a)  \
# 0   1  서울특별시  종로구  0.7425          0.8318               0.0057        0.7593
# 1   2  서울특별시   중구  0.4608          0.5462               0.0107        0.7254
# 2   3  서울특별시  용산구  0.4317          0.7288               0.0211        0.7754
# 3   4  서울특별시  성동구  0.4182          0.7288               0.0791        0.8332
# 4   5  서울특별시  광진구  0.3519          0.9434               0.0051        0.8541
#
#    인구 십만명당 사회적기업수  가족관계 만족도 b)
# 0          0.9981       0.5949
# 1          1.0000       0.2329
# 2          0.7194       0.2009
# 3          0.6783       0.0937
# 4          0.2461       0.2058

# %%
happy_leisure = read_excel('https://raw.githubusercontent.com/aidalabs/Lectures/master/LectureFiles/dataset/Korea_Happiness_Map-Leisure.xlsx')
happy_leisure.head()
# Out:
#    No     시도   구군      평균  여가활용 만족도 b)  노인 천명당 노인여가복지시설수  인구 십만명당 도서관수  \
# 0   1  서울특별시  종로구  0.6331       0.8409            0.1573        0.4523
# 1   2  서울특별시   중구  0.6691       0.6224            0.1467        0.5369
# 2   3  서울특별시  용산구  0.2817       0.6381            0.1628        0.2453
# 3   4  서울특별시  성동구  0.3257       0.5657            0.1859        0.3590
# 4   5  서울특별시  광진구  0.3313       0.6740            0.1443        0.2333
#
#    인구 십만명당 문화기반시설수  인구 천명당 체육관련 여가시설수
# 0           0.9997             0.5559
# 1           0.8441             0.9886
# 2           0.3715             0.2934
# 3           0.2768             0.4859
# 4           0.2058             0.6365

# %% [markdown]
# ### (2) 데이터 병합하기

# %%
city = list(happy_life['시도'].unique())
happy_merge = DataFrame( {'시도' : city} )
happy_merge
# Out:
#          시도
# 0     서울특별시
# 1     부산광역시
# 2     대구광역시
# 3     인천광역시
# 4     광주광역시
# 5     대전광역시
# 6     울산광역시
# 7   세종특별자치시
# 8       경기도
# 9       강원도
# 10     충청북도
# 11     충청남도
# 12     전라북도
# 13     전라남도
# 14     경상북도
# 15     경상남도
# 16  제주특별자치도

# %%
life = happy_life['삶의 만족도'].groupby(by=happy_life['시도']).mean()
happy_merge = merge(happy_merge, life, on='시도')
happy_merge.head()
# Out:
#       시도    삶의 만족도
# 0  서울특별시  0.490972
# 1  부산광역시  0.362081
# 2  대구광역시  0.363988
# 3  인천광역시  0.411480
# 4  광주광역시  0.484480

# %%
health = happy_health['평균'].groupby(by=happy_health['시도']).mean()
happy_merge = merge(happy_merge, health.rename('건강'), on='시도')
happy_merge.head()
# Out:
#       시도    삶의 만족도        건강
# 0  서울특별시  0.490972  0.569532
# 1  부산광역시  0.362081  0.511906
# 2  대구광역시  0.363988  0.482325
# 3  인천광역시  0.411480  0.339620
# 4  광주광역시  0.484480  0.632300

# %%
safe = happy_safe['평균'].groupby(by=happy_safe['시도']).mean()
happy_merge = merge(happy_merge, safe.rename('안전'), on='시도')
happy_merge.head()
# Out:
#       시도    삶의 만족도        건강        안전
# 0  서울특별시  0.490972  0.569532  0.552256
# 1  부산광역시  0.362081  0.511906  0.404875
# 2  대구광역시  0.363988  0.482325  0.358429
# 3  인천광역시  0.411480  0.339620  0.421020
# 4  광주광역시  0.484480  0.632300  0.266440

# %%
environ = happy_environ['평균'].groupby(by=happy_environ['시도']).mean()
happy_merge = merge(happy_merge, environ.rename('환경'), on='시도')
happy_merge.head()
# Out:
#       시도    삶의 만족도        건강        안전        환경
# 0  서울특별시  0.490972  0.569532  0.552256  0.470712
# 1  부산광역시  0.362081  0.511906  0.404875  0.448719
# 2  대구광역시  0.363988  0.482325  0.358429  0.552500
# 3  인천광역시  0.411480  0.339620  0.421020  0.515020
# 4  광주광역시  0.484480  0.632300  0.266440  0.607480

# %%
econo = happy_econo['평균'].groupby(by=happy_econo['시도']).mean()
happy_merge = merge(happy_merge, econo.rename('경제'), on='시도')
happy_merge.head()
# Out:
#       시도    삶의 만족도        건강        안전        환경        경제
# 0  서울특별시  0.490972  0.569532  0.552256  0.470712  0.532820
# 1  부산광역시  0.362081  0.511906  0.404875  0.448719  0.438038
# 2  대구광역시  0.363988  0.482325  0.358429  0.552500  0.393975
# 3  인천광역시  0.411480  0.339620  0.421020  0.515020  0.410820
# 4  광주광역시  0.484480  0.632300  0.266440  0.607480  0.387380

# %%
edu = happy_edu['평균'].groupby(by=happy_edu['시도']).mean()
happy_merge = merge(happy_merge, edu.rename('교육'), on='시도')
happy_merge.head()
# Out:
#       시도    삶의 만족도        건강        안전        환경        경제        교육
# 0  서울특별시  0.490972  0.569532  0.552256  0.470712  0.532820  0.399412
# 1  부산광역시  0.362081  0.511906  0.404875  0.448719  0.438038  0.504594
# 2  대구광역시  0.363988  0.482325  0.358429  0.552500  0.393975  0.585838
# 3  인천광역시  0.411480  0.339620  0.421020  0.515020  0.410820  0.502920
# 4  광주광역시  0.484480  0.632300  0.266440  0.607480  0.387380  0.689680

# %%
relation = happy_relation['평균'].groupby(by=happy_relation['시도']).mean()
happy_merge = merge(happy_merge, relation.rename('관계및사회참여'), on='시도')
happy_merge.head()
# Out:
#       시도    삶의 만족도        건강        안전        환경        경제        교육   관계및사회참여
# 0  서울특별시  0.490972  0.569532  0.552256  0.470712  0.532820  0.399412  0.390656
# 1  부산광역시  0.362081  0.511906  0.404875  0.448719  0.438038  0.504594  0.294719
# 2  대구광역시  0.363988  0.482325  0.358429  0.552500  0.393975  0.585838  0.407486
# 3  인천광역시  0.411480  0.339620  0.421020  0.515020  0.410820  0.502920  0.504920
# 4  광주광역시  0.484480  0.632300  0.266440  0.607480  0.387380  0.689680  0.637800

# %%
leisure = happy_leisure['평균'].groupby(by=happy_leisure['시도']).mean()
happy_merge = merge(happy_merge, leisure.rename('여가'), on='시도')
happy_merge
# Out:
#          시도    삶의 만족도        건강        안전        환경        경제        교육  \
# 0     서울특별시  0.490972  0.569532  0.552256  0.470712  0.532820  0.399412
# 1     부산광역시  0.362081  0.511906  0.404875  0.448719  0.438038  0.504594
# 2     대구광역시  0.363988  0.482325  0.358429  0.552500  0.393975  0.585838
# 3     인천광역시  0.411480  0.339620  0.421020  0.515020  0.410820  0.502920
# 4     광주광역시  0.484480  0.632300  0.266440  0.607480  0.387380  0.689680
# 5     대전광역시  0.407580  0.663580  0.206780  0.582380  0.416260  0.840780
# 6     울산광역시  0.471980  0.420040  0.477060  0.393440  0.642580  0.763240
# 7   세종특별자치시  0.907700  0.232000  0.157800  0.652400  0.511900  0.587000
# 8       경기도  0.426023  0.353952  0.325255  0.557977  0.468926  0.668619
# 9       강원도  0.619506  0.329506  0.548000  0.639839  0.386861  0.488533
# 10     충청북도  0.410100  0.401064  0.573155  0.466045  0.484755  0.592409
# 11     충청남도  0.553100  0.347433  0.481313  0.558173  0.402893  0.648047
# ...

# %% [markdown]
# ### (3) 데이터 검산하기

# %%
print(happy_merge['삶의 만족도'].mean())
print(happy_life['삶의 만족도'].mean())
# Out:
# 0.5181887062335198
# 0.4937618421052632

# %%
print(happy_merge['건강'].mean())
print(happy_health['평균'].mean())
# Out:
# 0.4094014744072605
# 0.40443508771929826

# %%
print(happy_merge['안전'].mean())
print(happy_safe['평균'].mean())
# Out:
# 0.42088164252386323
# 0.4569065789473684

# %%
print(happy_merge['환경'].mean())
print(happy_environ['평균'].mean())
# Out:
# 0.5794064414748389
# 0.5806381578947368

# %%
print(happy_merge['경제'].mean())
print(happy_econo['평균'].mean())
# Out:
# 0.4076346792607561
# 0.3894403508771929

# %%
print(happy_merge['교육'].mean())
print(happy_edu['평균'].mean())
# Out:
# 0.5786529913992841
# 0.5396557017543859

# %%
print(happy_merge['관계및사회참여'].mean())
print(happy_relation['평균'].mean())
# Out:
# 0.49763200954204206
# 0.468419298245614

# %%
print(happy_merge['여가'].mean())
print(happy_leisure['평균'].mean())
# Out:
# 0.46490970955241717
# 0.4623894736842106

# %%
happy_merge.isnull().sum()
# Out:
# 시도         0
# 삶의 만족도     0
# 건강         0
# 안전         0
# 환경         0
# 경제         0
# 교육         0
# 관계및사회참여    0
# 여가         0
# dtype: int64

# %% [markdown]
# ## 9.3 데이터 분석 및 시각화

# %% [markdown]
# ### (1) 데이터 분석

# %%
happy_merge.describe()
# Out:
#           삶의 만족도         건강         안전         환경         경제         교육  \
# count  17.000000  17.000000  17.000000  17.000000  17.000000  17.000000
# mean    0.518189   0.409401   0.420882   0.579406   0.407635   0.578653
# std     0.138257   0.127636   0.123557   0.097299   0.111265   0.125408
# min     0.362081   0.232000   0.157800   0.393440   0.196543   0.399412
# 25%     0.411480   0.329506   0.358429   0.515020   0.386861   0.488533
# 50%     0.490972   0.401064   0.446100   0.582380   0.410820   0.587000
# 75%     0.553100   0.482325   0.484835   0.652400   0.468926   0.648047
# max     0.907700   0.663580   0.573155   0.735600   0.642580   0.840780
#
#          관계및사회참여         여가
# count  17.000000  17.000000
# mean    0.497632   0.464910
# std     0.114394   0.176206
# min     0.294719   0.153587
# 25%     0.402183   0.347960
# 50%     0.487464   0.454980
# 75%     0.601532   0.632750
# max     0.676440   0.702891

# %%
happy_merge.mean(axis=0)
# Out:
# <ipython-input-39-4126a8f3a717>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   happy_merge.mean(axis=0)
# 삶의 만족도     0.518189
# 건강         0.409401
# 안전         0.420882
# 환경         0.579406
# 경제         0.407635
# 교육         0.578653
# 관계및사회참여    0.497632
# 여가         0.464910
# dtype: float64

# %%
happy_merge.mean(axis=1)
# Out:
# <ipython-input-40-ae8eabe2b777>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   happy_merge.mean(axis=1)
# 0     0.461637
# 1     0.389815
# 2     0.422433
# 3     0.418799
# 4     0.520068
# 5     0.497017
# 6     0.532900
# 7     0.521288
# 8     0.472481
# 9     0.526015
# 10    0.500400
# 11    0.508128
# 12    0.488729
# 13    0.500111
# 14    0.436254
# 15    0.482856
# 16    0.559075
# dtype: float64

# %%
happy_merge.set_index('시도').mean(axis=1)
# Out:
# 시도
# 서울특별시      0.461637
# 부산광역시      0.389815
# 대구광역시      0.422433
# 인천광역시      0.418799
# 광주광역시      0.520068
# 대전광역시      0.497017
# 울산광역시      0.532900
# 세종특별자치시    0.521288
# 경기도        0.472481
# 강원도        0.526015
# 충청북도       0.500400
# 충청남도       0.508128
# 전라북도       0.488729
# 전라남도       0.500111
# 경상북도       0.436254
# 경상남도       0.482856
# 제주특별자치도    0.559075
# dtype: float64

# %%
happy_merge.corr()
# Out:
# <ipython-input-42-46dedffec4e0>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   happy_merge.corr()
#            삶의 만족도        건강        안전        환경        경제        교육   관계및사회참여  \
# 삶의 만족도   1.000000 -0.570466 -0.191709  0.572262 -0.057815 -0.113522  0.519122
# 건강      -0.570466  1.000000 -0.210138 -0.357841  0.071809  0.242186 -0.175048
# 안전      -0.191709 -0.210138  1.000000 -0.124581 -0.142781 -0.519065 -0.444827
# 환경       0.572262 -0.357841 -0.124581  1.000000 -0.716187 -0.146646  0.169838
# 경제      -0.057815  0.071809 -0.142781 -0.716187  1.000000  0.451395  0.298562
# 교육      -0.113522  0.242186 -0.519065 -0.146646  0.451395  1.000000  0.462585
# 관계및사회참여  0.519122 -0.175048 -0.444827  0.169838  0.298562  0.462585  1.000000
# 여가       0.497880 -0.405151  0.382730  0.494416 -0.367461 -0.070109  0.216653
# ...

# %% [markdown]
# ### (2) 한글 폰트 설정

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (8,356 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns

font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
font_name = fm.FontProperties(fname=font_path, size=10).get_name()

plt.rc('font', family=font_name)

# %% [markdown]
# ### (3) 선 그래프로 시각화

# %%
plt.figure(figsize=(15,6))
items = list(happy_merge.columns[1:9])
for a in items:
    chartdata = happy_merge[a]
    plt.plot(chartdata, marker='o', label=a)

plt.xlabel('시도')
plt.ylabel('수치')
plt.xticks(range(17), happy_merge['시도'],fontsize=8)
plt.title('대한민국 행복지수')
plt.legend()
plt.grid()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
# ...

# %% [markdown]
# ### (4) 막대 그래프로 시각화

# %%
from numpy import *

happy_merge.plot(kind='bar', xlabel='시도', ylabel='수치', figsize=(15,20), grid=True, subplots=True)

plt.suptitle('대한민국 행복지수', fontsize=25)
plt.tight_layout(pad = 8, h_pad = 2)
plt.xticks(arange(17), city, rotation=360)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# <ipython-input-46-46655f469de5>:6: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   plt.tight_layout(pad = 8, h_pad = 2)
# <ipython-input-46-46655f469de5>:6: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from current font.
#   plt.tight_layout(pad = 8, h_pad = 2)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %% [markdown]
# ### (5) 히트맵 그래프로 시각화

# %%
import seaborn as sns

plt.figure(figsize=(15,13))
plt.title('대한민국 행복지수 상관관계', fontsize=25)
plt.rc('axes', unicode_minus=False)

correlation_mat = happy_merge.corr()
upp_mat = triu(correlation_mat)

sns.heatmap(correlation_mat, mask=upp_mat, annot=True, cmap='RdYlGn')
plt.show()
# Out:
# <ipython-input-47-bc39cb5edfb9>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_mat = happy_merge.corr()
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 49334 (\N{HANGUL SYLLABLE SALM}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 51032 (\N{HANGUL SYLLABLE YI}) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 47564 (\N{HANGUL SYLLABLE MAN}) missing from current font.
#   fig.canvas.draw()
# ...
