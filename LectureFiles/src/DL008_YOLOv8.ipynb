# %%
import os

# %%
if not os.path.exists('./data/'):
    os.makedirs('./data/')

# %%
import gdown

# %%
file_id = "1KnJWPp_GuUi8a_D7iqkB4pOLaEGVg8O9"
output = "data/Aquarium_Data.zip" # 저장 위치 및 저장할 파일 이름
gdown.download(id=file_id, output=output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1KnJWPp_GuUi8a_D7iqkB4pOLaEGVg8O9
# To: /content/data/Aquarium_Data.zip
# 100%|██████████| 70.2M/70.2M [00:02<00:00, 31.0MB/s]
# 'data/Aquarium_Data.zip'

# %%
import zipfile

# %%
with zipfile.ZipFile('./data/Aquarium_Data.zip') as target_file:
    target_file.extractall('./Aquarium_Data/')

# %%
# !cat ./Aquarium_Data/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 7
# names: ['fish', 'jellyfish', 'penguin', 'puffin', 'shark', 'starfish', 'stingray']
#
# roboflow:
#   workspace: brad-dwyer
#   project: aquarium-combined
#   version: 2
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/brad-dwyer/aquarium-combined/dataset/2

# %%
# !pip install PyYAML

# %%
import yaml

# %%
data = {
    'train': '/content/Aquarium_Data/train/images/',
    'val': '/content/Aquarium_Data/valid/images/',
    'test': '/content/Aquarium_Data/train/images/',
    'names': ['fish', 'jellyfish', 'penguin', 'puffin', 'shark', 'starfish', 'stingray'],
    'nc': 7
}

# %%
with open('/content/Aquarium_Data/Aquarium_Data.yaml', 'w') as f:
    yaml.dump(data, f)

# %%
with open('/content/Aquarium_Data/Aquarium_Data.yaml', 'r') as f:
    aquarium_yaml = yaml.safe_load(f)
    display(aquarium_yaml)
# Out:
# {'names': ['fish',
#   'jellyfish',
#   'penguin',
#   'puffin',
#   'shark',
#   'starfish',
#   'stingray'],
#  'nc': 7,
#  'test': '/content/Aquarium_Data/train/images/',
#  'train': '/content/Aquarium_Data/train/images/',
#  'val': '/content/Aquarium_Data/valid/images/'}

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.2/613.2 kB 5.0 MB/s eta 0:00:00
# ...

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.167 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.4/78.2 GB disk)

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 85.0MB/s]

# %%
print(type(model.names), len(model.names))
print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %%
model.train(data='/content/Aquarium_Data/Aquarium_Data.yaml', epochs=100, patience=30, batch=32, imgsz=416)
# Out:
# Ultralytics YOLOv8.0.167 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
print(type(model.names), len(model.names))
print(model.names)
# Out:
# <class 'dict'> 7
# {0: 'fish', 1: 'jellyfish', 2: 'penguin', 3: 'puffin', 4: 'shark', 5: 'starfish', 6: 'stingray'}

# %%
results = model.predict(source='/content/Aquarium_Data/test/images/', save=True)
# Out:
# image 1/63 /content/Aquarium_Data/test/images/IMG_2289_jpeg_jpg.rf.fe2a7a149e7b11f2313f5a7b30386e85.jpg: 416x320 1 puffin, 98.6ms
# image 2/63 /content/Aquarium_Data/test/images/IMG_2301_jpeg_jpg.rf.2c19ae5efbd1f8611b5578125f001695.jpg: 416x320 19 penguins, 7.6ms
# image 3/63 /content/Aquarium_Data/test/images/IMG_2319_jpeg_jpg.rf.6e20bf97d17b74a8948aa48776c40454.jpg: 416x320 7 penguins, 7.3ms
# image 4/63 /content/Aquarium_Data/test/images/IMG_2347_jpeg_jpg.rf.7c71ac4b9301eb358cd4a832844dedcb.jpg: 416x320 1 penguin, 6.9ms
# image 5/63 /content/Aquarium_Data/test/images/IMG_2354_jpeg_jpg.rf.396e872c7fb0a95e911806986995ee7a.jpg: 416x320 4 penguins, 11.1ms
# image 6/63 /content/Aquarium_Data/test/images/IMG_2371_jpeg_jpg.rf.54505f60b6706da151c164188c305849.jpg: 416x320 3 fishs, 10.5ms
# image 7/63 /content/Aquarium_Data/test/images/IMG_2379_jpeg_jpg.rf.7dc3160c937072d26d4624c6c48e904d.jpg: 416x320 1 fish, 10.4ms
# ...

# %% [markdown]
# ## 섬유AI 데이터

# %%
file_id = "16L1zxYt01jb3ed42-W6XIzQyB2jKtRJh"
output = "data/Fabric_Data.zip" # 저장 위치 및 저장할 파일 이름
gdown.download(id=file_id, output=output, quiet=False)

# %%
https://drive.google.com/file/d/16L1zxYt01jb3ed42-W6XIzQyB2jKtRJh/view?usp=sharing

# %%
file_id = "1Q2aafj6FSZD2gUeHVkrS-foJEHgEGvxz"
output = "data/Fabric_Data_Modified.zip" # 저장 위치 및 저장할 파일 이름
gdown.download(id=file_id, output=output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Q2aafj6FSZD2gUeHVkrS-foJEHgEGvxz
# To: /content/data/Fabric_Data.zip
# 100%|██████████| 419M/419M [00:10<00:00, 39.2MB/s]
# 'data/Fabric_Data.zip'

# %%
with zipfile.ZipFile('./data/Fabric_Data.zip') as target_file:
    target_file.extractall('./Fabric_Data/')

# %%
data = {
    'train': '/content/Fabric_Data/train/images/',
    'val': '/content/Fabric_Data/val/images/',
    'test': '/content/Fabric_Data/train/images/',
    'names': ['Bad', 'Good'],
    'nc': 2
}

# %%
with open('/content/Fabric_Data/Fabric_Data.yaml', 'w') as f:
    yaml.dump(data, f)

# %%
with open('/content/Fabric_Data/Fabric_Data.yaml', 'r') as f:
    fabric_yaml = yaml.safe_load(f)
    display(fabric_yaml)
# Out:
# {'names': ['Bad', 'Good'],
#  'nc': 2,
#  'test': '/content/Fabric_Data/train/images/',
#  'train': '/content/Fabric_Data/train/images/',
#  'val': '/content/Fabric_Data/val/images/'}

# %%
model = YOLO('yolov8n.pt')

# %%
print(type(model.names), len(model.names))
print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %%
model.train(data='/content/Fabric_Data/Fabric_Data.yaml', epochs=100, patience=30, batch=16, imgsz=3024)
# Out:
# Ultralytics YOLOv8.0.167 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
print(type(model.names), len(model.names))
print(model.names)

# %%
results = model.predict(source='/content/Fabric_Data/test/images/', save=True)
