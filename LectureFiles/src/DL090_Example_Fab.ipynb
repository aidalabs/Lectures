# %% [markdown]
# # 데이터파일 확보 및 압축풀기

# %%
import os
import zipfile

# %%
with zipfile.ZipFile('./data_source/SELECTSTAR.zip') as target_file:
    target_file.extractall('./data_source/SELECTSTAR/')

# %% [markdown]
# # Json 파일에서 데이터를 추출하여 YOLO용 txt파일 만들기

# %%
import json

# %%
json_dir = './data_source/SELECTSTAR/3_button_json/'
json_list = [name for name in os.listdir(json_dir)]
json_list.sort()

# %%
label_dir = './data_source/SELECTSTAR/button_labels/'
if not os.path.exists(label_dir):
    os.makedirs(label_dir)

# %%
for name in json_list:
    with open(json_dir + name) as file:
        obj = json.load(file)

        label = '0' if obj['label']=='false' else '1'
        w = obj['bbox']['x2'] - obj['bbox']['x1']
        h = obj['bbox']['y2'] - obj['bbox']['y1']
        x = obj['bbox']['x2'] - w/2
        y = obj['bbox']['y2'] - h/2

        label_filename = label_dir + os.path.splitext(name)[0] + '.txt'
        wfile = open(label_filename, 'w')
        wfile.write(f"0 {x:f} {y:f} {w:f} {h:f}\n")        
        wfile.close()

# %% [markdown]
# # 데이터 파일을 훈련용, 검증용, 테스트용으로 분할하기
# - 분할 시, 불량과 양품의 비율을 맞추어야 하므로 good/bad로 분류한 후 분할하고, 다시 합치도록 함

# %%
import glob
import shutil

# %%
if not os.path.exists('./data_source/GB/bad/'):
    os.makedirs('./data_source/GB/bad/')

if not os.path.exists('./data_source/GB/good/'):
    os.makedirs('./data_source/GB/good/')

# %%
bad_list = glob.glob('./data_source/SELECTSTAR/2_button_image/Button_F*.jpg')

for src_path in bad_list:
    dst_path = './data_source/GB/bad/' + os.path.basename(src_path)
    shutil.copy2(src_path, dst_path)

# %%
good_list = glob.glob('./data_source/SELECTSTAR/2_button_image/Button_T*.jpg')

for src_path in good_list:
    dst_path = './data_source/GB/good/' + os.path.basename(src_path)
    shutil.copy2(src_path, dst_path)

# %% [markdown]
# - 데이터 분할을 위한 splitfolders 라이브러리 설치 후 분할 작업 수행

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Using cached split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders as sf

# %%
sf.ratio("./data_source/GB/", output="./dataset/", seed=1357, ratio=(.8, .1, .1))

# %%
if not os.path.exists('./dataset/test/images/'):
    os.makedirs('./dataset/test/images/')

if not os.path.exists('./dataset/train/images/'):
    os.makedirs('./dataset/train/images/')

if not os.path.exists('./dataset/val/images/'):
    os.makedirs('./dataset/val/images/')

# %%
if not os.path.exists('./dataset/test/labels/'):
    os.makedirs('./dataset/test/labels/')

if not os.path.exists('./dataset/train/labels/'):
    os.makedirs('./dataset/train/labels/')

if not os.path.exists('./dataset/val/labels/'):
    os.makedirs('./dataset/val/labels/')

# %%
dest_dir = './dataset/test/images/'
file_list = glob.glob('./dataset/test/bad/*.*')

for src_path in file_list:
    shutil.move(src_path, dest_dir + os.path.basename(src_path))

file_list = glob.glob('./dataset/test/good/*.*')

for src_path in file_list:
    shutil.move(src_path, dest_dir + os.path.basename(src_path))

if os.path.exists('./dataset/test/bad/'):
    os.rmdir('./dataset/test/bad/')
if os.path.exists('./dataset/test/good/'):
    os.rmdir('./dataset/test/good/')

# %%
dest_dir = './dataset/train/images/'
file_list = glob.glob('./dataset/train/bad/*.*')

for src_path in file_list:
    shutil.move(src_path, dest_dir + os.path.basename(src_path))

file_list = glob.glob('./dataset/train/good/*.*')

for src_path in file_list:
    shutil.move(src_path, dest_dir + os.path.basename(src_path))

if os.path.exists('./dataset/train/bad/'):
    os.rmdir('./dataset/train/bad/')
if os.path.exists('./dataset/train/good/'):
    os.rmdir('./dataset/train/good/')

# %%
dest_dir = './dataset/val/images/'
file_list = glob.glob('./dataset/val/bad/*.*')

for src_path in file_list:
    shutil.move(src_path, dest_dir + os.path.basename(src_path))

file_list = glob.glob('./dataset/val/good/*.*')

for src_path in file_list:
    shutil.move(src_path, dest_dir + os.path.basename(src_path))

if os.path.exists('./dataset/val/bad/'):
    os.rmdir('./dataset/val/bad/')
if os.path.exists('./dataset/val/good/'):
    os.rmdir('./dataset/val/good/')

# %%
src_dir = './data_source/SELECTSTAR/button_labels/'
dest_dir = './dataset/test/labels/'
file_list = os.listdir('./dataset/test/images/')

for src_path in file_list:
    shutil.move(src_dir + src_path.replace('.jpg', '.txt'), dest_dir)

# %%
src_dir = './data_source/SELECTSTAR/button_labels/'
dest_dir = './dataset/train/labels/'
file_list = os.listdir('./dataset/train/images/')

for src_path in file_list:
    shutil.move(src_dir + src_path.replace('.jpg', '.txt'), dest_dir)

# %%
src_dir = './data_source/SELECTSTAR/button_labels/'
dest_dir = './dataset/val/labels/'
file_list = os.listdir('./dataset/val/images/')

for src_path in file_list:
    shutil.move(src_dir + src_path.replace('.jpg', '.txt'), dest_dir)

# %% [markdown]
# # YAML 파일 만들기

# %%
import yaml

# %%
data = {
    'train': './dataset/train/images/',
    'val': './dataset/val/images/',
    'test': './dataset/test/images/',
    'names': ['bad', 'good'],
    'nc': 2
}

# %%
with open('./fab.yaml', 'w') as f:
    yaml.dump(data, f)

# %%
with open('./fab.yaml', 'r') as f:
    aquarium_yaml = yaml.safe_load(f)
    display(aquarium_yaml)
# Out:
# {'names': ['bad', 'good'],
#  'nc': 2,
#  'test': './dataset/test/images/',
#  'train': './dataset/train/images/',
#  'val': './dataset/val/images/'}

# %% [markdown]
# # YOLO 모델 설치

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Using cached ultralytics-8.0.172-py3-none-any.whl (614 kB)
# Collecting torchvision>=0.9.0
#   Using cached torchvision-0.15.2-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
# Collecting numpy>=1.22.2
#   Using cached numpy-1.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Collecting pillow>=7.1.2
#   Using cached Pillow-10.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (3.4 MB)
# Collecting py-cpuinfo
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting tqdm>=4.64.0
#   Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Collecting pandas>=1.1.4
#   Using cached pandas-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
# Requirement already satisfied: psutil in ./lib/python3.10/site-packages (from ultralytics) (5.9.5)
# Collecting opencv-python>=4.6.0
#   Using cached opencv_python-4.8.0.76-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.7 MB)
# Requirement already satisfied: requests>=2.23.0 in ./lib/python3.10/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: pyyaml>=5.3.1 in ./lib/python3.10/site-packages (from ultralytics) (6.0.1)
# Collecting seaborn>=0.11.0
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# Collecting matplotlib>=3.2.2
#   Using cached matplotlib-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Collecting scipy>=1.4.1
#   Using cached scipy-1.11.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.3 MB)
# Collecting torch>=1.8.0
#   Using cached torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.42.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
# Requirement already satisfied: packaging>=20.0 in ./lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics) (23.1)
# Collecting pyparsing<3.1,>=2.3.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./lib/python3.10/site-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Collecting pytz>=2020.1
#   Using cached pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.2.0)
# Collecting networkx
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Collecting nvidia-nccl-cu11==2.14.3
#   Using cached nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
# Collecting sympy
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Collecting nvidia-cufft-cu11==10.9.0.58
#   Using cached nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
# Collecting triton==2.0.0
#   Using cached triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Requirement already satisfied: jinja2 in ./lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Collecting nvidia-cuda-cupti-cu11==11.7.101
#   Using cached nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
# Collecting nvidia-cusolver-cu11==11.4.0.1
#   Using cached nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
# Collecting nvidia-nvtx-cu11==11.7.91
#   Using cached nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
# Collecting nvidia-cusparse-cu11==11.7.4.91
#   Using cached nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
# Collecting nvidia-curand-cu11==10.2.10.91
#   Using cached nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Requirement already satisfied: typing-extensions in ./lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.7.1)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Collecting filelock
#   Using cached filelock-3.12.3-py3-none-any.whl (11 kB)
# Collecting wheel
#   Using cached wheel-0.41.2-py3-none-any.whl (64 kB)
# Requirement already satisfied: setuptools in ./lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8.0->ultralytics) (59.6.0)
# Collecting cmake
#   Using cached cmake-3.27.4.1-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (26.1 MB)
# Collecting lit
#   Using cached lit-16.0.6-py3-none-any.whl
# Requirement already satisfied: six>=1.5 in ./lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Collecting mpmath>=0.19
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: pytz, py-cpuinfo, mpmath, lit, cmake, wheel, tzdata, tqdm, sympy, pyparsing, pillow, nvidia-nccl-cu11, nvidia-cufft-cu11, nvidia-cuda-nvrtc-cu11, numpy, networkx, kiwisolver, fonttools, filelock, cycler, scipy, pandas, opencv-python, nvidia-nvtx-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, contourpy, nvidia-cusolver-cu11, nvidia-cudnn-cu11, matplotlib, seaborn, triton, torch, torchvision, ultralytics
# Successfully installed cmake-3.27.4.1 contourpy-1.1.0 cycler-0.11.0 filelock-3.12.3 fonttools-4.42.1 kiwisolver-1.4.5 lit-16.0.6 matplotlib-3.7.2 mpmath-1.3.0 networkx-3.1 numpy-1.25.2 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 opencv-python-4.8.0.76 pandas-2.1.0 pillow-10.0.0 py-cpuinfo-9.0.0 pyparsing-3.0.9 pytz-2023.3.post1 scipy-1.11.2 seaborn-0.12.2 sympy-1.12 torch-2.0.1 torchvision-0.15.2 tqdm-4.66.1 triton-2.0.0 tzdata-2023.3 ultralytics-8.0.172 wheel-0.41.2

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.172 🚀 Python-3.10.12 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 4080 Laptop GPU, 12010MiB)
# Setup complete ✅ (32 CPUs, 15.2 GB RAM, 109.5/937.3 GB disk)

# %% [markdown]
# # 사전학습 모델 설정

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')

# %%
yaml_path = os.getcwd()+'/fab.yaml'
model.train(data=yaml_path, epochs=100, patience=30, batch=32, imgsz=416)
# Out:
# Ultralytics YOLOv8.0.172 🚀 Python-3.10.12 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 4080 Laptop GPU, 12010MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/home/seokhwan/workspace/fabr/fab.yaml, epochs=100, patience=30, batch=32, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 225 layers, 3011238 parameters, 3011222 gradients
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /home/seokhwan/workspace/fabr/dataset/train/labels... 160 images, 0 backgrounds, 1 corrupt: 100%|██████████| 160/160 [00:00<
# train: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/train/images/Button_T_W_59.jpg: ignoring corrupt image/label: Label class 16 exceeds dataset class count 2. Possible class labels are 0-1
# train: New cache created: /home/seokhwan/workspace/fabr/dataset/train/labels.cache
# val: Scanning /home/seokhwan/workspace/fabr/dataset/val/labels... 20 images, 0 backgrounds, 0 corrupt: 100%|██████████| 20/20 [00:00<00:00,
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_F_B_07.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_F_B_23.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_F_B_27.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_F_B_34.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_F_W_52.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_F_W_60.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_F_W_61.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_F_W_64.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_F_W_80.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_T_B_07.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_T_B_27.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_T_B_34.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_T_W_52.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_T_W_60.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_T_W_61.jpg: corrupt JPEG restored and saved
# val: WARNING ⚠️ /home/seokhwan/workspace/fabr/dataset/val/images/Button_T_W_80.jpg: corrupt JPEG restored and saved
# val: New cache created: /home/seokhwan/workspace/fabr/dataset/val/labels.cache
# Plotting labels to runs/detect/train3/labels.jpg...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 416 train, 416 val
# Using 8 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100       1.8G     0.9125      3.218      1.027         53        416: 100%|██████████| 5/5 [00:01<00:00,  3.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 10.14it/s]
#                    all         20         20    0.00414          1      0.185      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      1.83G     0.7138      2.965      0.981         50        416: 100%|██████████| 5/5 [00:00<00:00,  7.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  8.83it/s]
#                    all         20         20    0.00383          1      0.684      0.601
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      1.83G     0.6084      1.898     0.9146         52        416: 100%|██████████| 5/5 [00:01<00:00,  4.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 11.78it/s]
#                    all         20         20    0.00345          1      0.628      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      1.83G     0.6295      1.457     0.9306         68        416: 100%|██████████| 5/5 [00:00<00:00,  5.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 11.34it/s]
#                    all         20         20      0.484          1      0.611        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      1.83G     0.6037      1.353     0.9204         44        416: 100%|██████████| 5/5 [00:00<00:00,  8.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 11.56it/s]
#                    all         20         20      0.669       0.68      0.705      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      1.83G     0.6046      1.221      0.903         49        416: 100%|██████████| 5/5 [00:00<00:00,  8.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 11.27it/s]
#                    all         20         20      0.848      0.463      0.757      0.643
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      1.83G     0.5848      1.245     0.9097         52        416: 100%|██████████| 5/5 [00:00<00:00,  9.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 12.52it/s]
#                    all         20         20      0.679      0.213      0.769       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      1.83G     0.5417      1.069      0.913         52        416: 100%|██████████| 5/5 [00:00<00:00, 10.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 23.73it/s]
#                    all         20         20      0.739      0.858      0.844      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      1.83G     0.5906      1.055     0.9083         59        416: 100%|██████████| 5/5 [00:00<00:00,  9.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 22.64it/s]
#                    all         20         20      0.674       0.65      0.654      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      1.83G     0.5683      1.141     0.8814         59        416: 100%|██████████| 5/5 [00:00<00:00,  9.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 14.59it/s]
#                    all         20         20       0.58      0.582       0.61      0.404
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      1.84G      0.624       1.08     0.9313         55        416: 100%|██████████| 5/5 [00:00<00:00, 11.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 19.52it/s]
#                    all         20         20      0.529      0.649      0.501      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      1.84G     0.5985     0.9862     0.9011         63        416: 100%|██████████| 5/5 [00:00<00:00, 10.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 22.50it/s]
#                    all         20         20      0.663      0.418      0.649      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      1.84G     0.5842     0.9884     0.9261         67        416: 100%|██████████| 5/5 [00:00<00:00, 11.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 19.19it/s]
#                    all         20         20      0.612      0.505      0.538        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      1.84G     0.6158     0.9312     0.9171         65        416: 100%|██████████| 5/5 [00:00<00:00, 10.16it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 22.83it/s]
#                    all         20         20      0.742       0.47      0.521      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      1.84G     0.5661     0.9379     0.9101         46        416: 100%|██████████| 5/5 [00:00<00:00,  9.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 20.61it/s]
#                    all         20         20      0.728      0.654      0.637      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      1.84G      0.569     0.9962     0.9066         52        416: 100%|██████████| 5/5 [00:00<00:00, 10.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 24.92it/s]
#                    all         20         20      0.461      0.702      0.653      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      1.84G      0.605     0.9769     0.9094         62        416: 100%|██████████| 5/5 [00:00<00:00, 11.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 25.28it/s]
#                    all         20         20      0.708        0.5      0.569      0.422
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      1.84G     0.5588     0.9255     0.9168         56        416: 100%|██████████| 5/5 [00:00<00:00, 11.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 24.13it/s]
#                    all         20         20      0.424      0.423      0.327      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      1.84G     0.5791     0.8995     0.9294         45        416: 100%|██████████| 5/5 [00:00<00:00, 11.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 25.53it/s]
#                    all         20         20      0.687       0.25      0.302      0.235
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      1.84G     0.5861     0.8767     0.9106         57        416: 100%|██████████| 5/5 [00:00<00:00, 11.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.95it/s]
#                    all         20         20      0.456      0.461      0.487      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      1.84G     0.5751     0.8757     0.9155         59        416: 100%|██████████| 5/5 [00:00<00:00, 11.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 24.64it/s]
#                    all         20         20      0.293       0.25      0.267       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      1.84G     0.6031     0.9352     0.9383         57        416: 100%|██████████| 5/5 [00:00<00:00, 11.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.46it/s]
#                    all         20         20      0.486       0.35      0.272      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      1.84G     0.5901     0.9302     0.8996         48        416: 100%|██████████| 5/5 [00:00<00:00, 11.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.45it/s]
#                    all         20         20      0.842       0.15      0.411      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      1.84G     0.6082     0.9162     0.9166         48        416: 100%|██████████| 5/5 [00:00<00:00, 11.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.74it/s]
#                    all         20         20      0.513      0.696      0.628      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      1.84G      0.549     0.7565     0.9017         56        416: 100%|██████████| 5/5 [00:00<00:00, 11.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.00it/s]
#                    all         20         20      0.777      0.605      0.636      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      1.84G     0.5747     0.8202     0.9222         47        416: 100%|██████████| 5/5 [00:00<00:00, 11.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.79it/s]
#                    all         20         20      0.728      0.695      0.617      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      1.84G     0.5763     0.7686      0.916         54        416: 100%|██████████| 5/5 [00:00<00:00, 11.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.02it/s]
#                    all         20         20      0.586      0.719      0.669      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      1.84G     0.5604     0.7732     0.9213         51        416: 100%|██████████| 5/5 [00:00<00:00, 11.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.63it/s]
#                    all         20         20      0.797      0.781      0.731      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      1.84G     0.5756     0.8342     0.9196         57        416: 100%|██████████| 5/5 [00:00<00:00, 11.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 25.17it/s]
#                    all         20         20      0.788       0.84      0.827      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      1.84G     0.5595     0.8514     0.9116         59        416: 100%|██████████| 5/5 [00:00<00:00, 11.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 13.89it/s]
#                    all         20         20      0.691      0.861      0.865      0.738
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      1.84G     0.5551     0.7899     0.9087         52        416: 100%|██████████| 5/5 [00:00<00:00, 11.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.10it/s]
#                    all         20         20      0.634        0.9      0.807      0.681
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      1.84G     0.5538     0.7968     0.9101         47        416: 100%|██████████| 5/5 [00:00<00:00, 11.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.06it/s]
#                    all         20         20      0.739       0.85      0.797      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      1.84G     0.5135     0.7799     0.9178         54        416: 100%|██████████| 5/5 [00:00<00:00, 11.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.02it/s]
#                    all         20         20      0.794       0.65       0.73      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      1.84G     0.5378     0.7771     0.9306         51        416: 100%|██████████| 5/5 [00:00<00:00, 11.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.72it/s]
#                    all         20         20      0.746       0.65      0.663       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      1.84G     0.5289     0.7443     0.9077         43        416: 100%|██████████| 5/5 [00:00<00:00, 11.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.57it/s]
#                    all         20         20      0.795        0.7      0.828      0.699
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      1.84G      0.528     0.6846     0.8984         60        416: 100%|██████████| 5/5 [00:00<00:00, 11.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.13it/s]
#                    all         20         20      0.796      0.883      0.845      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      1.84G     0.5427     0.6981      0.911         53        416: 100%|██████████| 5/5 [00:00<00:00, 11.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 25.28it/s]
#                    all         20         20      0.801      0.843      0.879      0.779
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      1.84G     0.5304     0.6872     0.9212         51        416: 100%|██████████| 5/5 [00:00<00:00, 11.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 28.13it/s]
#                    all         20         20      0.833      0.833      0.912      0.797
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      1.84G     0.4791     0.6775     0.8763         50        416: 100%|██████████| 5/5 [00:00<00:00, 11.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 25.52it/s]
#                    all         20         20      0.834      0.836      0.833      0.746
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      1.84G     0.5023     0.6472     0.8858         59        416: 100%|██████████| 5/5 [00:00<00:00, 11.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.94it/s]
#                    all         20         20      0.851        0.8      0.814      0.731
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      1.84G     0.5222      0.659     0.9126         55        416: 100%|██████████| 5/5 [00:00<00:00, 11.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.59it/s]
#                    all         20         20      0.905      0.899      0.932      0.836
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      1.84G     0.5264     0.6149     0.9098         64        416: 100%|██████████| 5/5 [00:00<00:00, 11.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.52it/s]
#                    all         20         20      0.749       0.77      0.786      0.721
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      1.84G     0.5092     0.6275     0.9153         56        416: 100%|██████████| 5/5 [00:00<00:00, 11.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.29it/s]
#                    all         20         20      0.758       0.85       0.91      0.816
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      1.84G     0.4875     0.5835     0.8919         66        416: 100%|██████████| 5/5 [00:00<00:00, 11.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.63it/s]
#                    all         20         20      0.946       0.95      0.962      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      1.84G     0.4893     0.6259       0.91         57        416: 100%|██████████| 5/5 [00:00<00:00, 11.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 25.87it/s]
#                    all         20         20       0.95       0.95       0.99      0.896
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      1.84G     0.4878     0.5936     0.8936         61        416: 100%|██████████| 5/5 [00:00<00:00, 11.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.95it/s]
#                    all         20         20      0.945      0.989      0.995      0.913
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      1.84G     0.4995     0.6402     0.9027         61        416: 100%|██████████| 5/5 [00:00<00:00, 11.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.68it/s]
#                    all         20         20      0.833      0.836      0.891      0.811
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      1.84G     0.4948     0.6197     0.8974         56        416: 100%|██████████| 5/5 [00:00<00:00, 11.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.81it/s]
#                    all         20         20      0.835      0.886      0.924      0.842
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      1.84G     0.4678     0.5489     0.8883         49        416: 100%|██████████| 5/5 [00:00<00:00, 11.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.82it/s]
#                    all         20         20      0.971       0.93       0.99      0.893
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      1.84G     0.5021     0.5901     0.8915         60        416: 100%|██████████| 5/5 [00:00<00:00, 11.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.81it/s]
#                    all         20         20       0.86       0.88      0.977      0.876
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      1.84G     0.4582     0.5174     0.8782         51        416: 100%|██████████| 5/5 [00:00<00:00, 11.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.47it/s]
#                    all         20         20      0.816      0.991      0.963      0.857
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      1.84G     0.5032     0.5503     0.8999         55        416: 100%|██████████| 5/5 [00:00<00:00, 11.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.32it/s]
#                    all         20         20      0.788       0.96      0.986      0.874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      1.84G     0.4673     0.5476     0.8755         53        416: 100%|██████████| 5/5 [00:00<00:00, 11.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.55it/s]
#                    all         20         20       0.65      0.847      0.954      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      1.84G     0.4768     0.5401     0.8881         58        416: 100%|██████████| 5/5 [00:00<00:00, 11.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.84it/s]
#                    all         20         20      0.777      0.848      0.953      0.855
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      1.84G     0.4656     0.5092     0.8942         49        416: 100%|██████████| 5/5 [00:00<00:00, 11.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 25.73it/s]
#                    all         20         20      0.818      0.995      0.964      0.859
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      1.84G     0.4446      0.492     0.8811         48        416: 100%|██████████| 5/5 [00:00<00:00, 11.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.70it/s]
#                    all         20         20       0.88      0.899      0.977      0.893
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      1.84G     0.4619     0.5152     0.8852         56        416: 100%|██████████| 5/5 [00:00<00:00, 11.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.74it/s]
#                    all         20         20      0.785      0.935      0.973      0.887
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      1.84G       0.44       0.52      0.875         58        416: 100%|██████████| 5/5 [00:00<00:00, 11.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.52it/s]
#                    all         20         20      0.715      0.809      0.915      0.821
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      1.84G     0.4417     0.5048     0.8771         49        416: 100%|██████████| 5/5 [00:00<00:00, 11.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.10it/s]
#                    all         20         20      0.723      0.689      0.786      0.687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      1.84G     0.4834     0.5235     0.9023         52        416: 100%|██████████| 5/5 [00:00<00:00, 11.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.91it/s]
#                    all         20         20       0.78      0.895      0.881      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      1.84G     0.4599     0.5071     0.8975         63        416: 100%|██████████| 5/5 [00:00<00:00, 11.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.26it/s]
#                    all         20         20      0.873       0.85      0.892      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      1.84G     0.4337     0.4593     0.8704         52        416: 100%|██████████| 5/5 [00:00<00:00, 11.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.36it/s]
#                    all         20         20      0.809       0.95       0.93      0.834
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      1.84G     0.4292     0.4777     0.8879         50        416: 100%|██████████| 5/5 [00:00<00:00, 11.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.12it/s]
#                    all         20         20      0.873      0.946      0.968      0.905
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      1.84G     0.4257     0.4856     0.8733         64        416: 100%|██████████| 5/5 [00:00<00:00, 11.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.98it/s]
#                    all         20         20      0.841      0.934      0.982        0.9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      1.84G     0.4266     0.5263     0.8847         49        416: 100%|██████████| 5/5 [00:00<00:00, 11.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.45it/s]
#                    all         20         20       0.87       0.95       0.99        0.9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      1.84G     0.4402     0.5073     0.8932         53        416: 100%|██████████| 5/5 [00:00<00:00, 11.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.85it/s]
#                    all         20         20      0.974          1      0.995      0.934
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      1.84G     0.4323     0.4653     0.8797         57        416: 100%|██████████| 5/5 [00:00<00:00, 11.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.94it/s]
#                    all         20         20      0.895        0.9      0.963      0.903
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      1.84G     0.4154     0.4409     0.8794         64        416: 100%|██████████| 5/5 [00:00<00:00, 11.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.84it/s]
#                    all         20         20      0.859      0.897      0.887      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      1.84G     0.4256     0.5268     0.8819         56        416: 100%|██████████| 5/5 [00:00<00:00, 11.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.03it/s]
#                    all         20         20      0.864      0.946      0.968      0.876
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      1.84G       0.41     0.4772     0.8754         42        416: 100%|██████████| 5/5 [00:00<00:00, 11.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.88it/s]
#                    all         20         20      0.908        0.9       0.97      0.881
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      1.84G     0.4306     0.5345     0.8929         48        416: 100%|██████████| 5/5 [00:00<00:00, 11.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.91it/s]
#                    all         20         20      0.903      0.995       0.97      0.874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      1.84G     0.4227     0.4875     0.8801         54        416: 100%|██████████| 5/5 [00:00<00:00, 11.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.50it/s]
#                    all         20         20      0.938      0.975       0.99      0.884
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      1.84G     0.4119     0.4802     0.8839         56        416: 100%|██████████| 5/5 [00:00<00:00, 11.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.04it/s]
#                    all         20         20       0.97          1      0.995      0.899
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      1.84G     0.3888     0.4292     0.8757         59        416: 100%|██████████| 5/5 [00:00<00:00, 11.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 28.27it/s]
#                    all         20         20      0.984       0.96      0.995        0.9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      1.84G     0.4013     0.4244     0.8683         65        416: 100%|██████████| 5/5 [00:00<00:00, 11.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.00it/s]
#                    all         20         20      0.943      0.954      0.995      0.891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      1.84G     0.4053     0.4219     0.8759         57        416: 100%|██████████| 5/5 [00:00<00:00, 11.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.41it/s]
#                    all         20         20      0.854       0.98      0.995      0.903
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      1.84G     0.3957     0.4128     0.8734         66        416: 100%|██████████| 5/5 [00:00<00:00, 11.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.99it/s]
#                    all         20         20      0.932          1      0.995      0.912
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      1.84G     0.4123     0.4814     0.8842         57        416: 100%|██████████| 5/5 [00:00<00:00, 11.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.78it/s]
#                    all         20         20      0.923      0.943      0.986       0.88
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      1.84G     0.4108     0.4361     0.8745         59        416: 100%|██████████| 5/5 [00:00<00:00, 11.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.86it/s]
#                    all         20         20      0.891       0.95      0.982      0.894
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      1.84G     0.4087     0.4476     0.8775         61        416: 100%|██████████| 5/5 [00:00<00:00, 11.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.00it/s]
#                    all         20         20      0.854          1      0.982      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      1.84G     0.4013      0.445      0.874         46        416: 100%|██████████| 5/5 [00:00<00:00, 11.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.39it/s]
#                    all         20         20      0.909        0.9      0.954      0.879
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      1.84G      0.392     0.4219     0.8677         48        416: 100%|██████████| 5/5 [00:00<00:00, 11.48it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 28.41it/s]
#                    all         20         20      0.831      0.989      0.963      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      1.84G     0.4049     0.4357      0.873         64        416: 100%|██████████| 5/5 [00:00<00:00, 11.50it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.18it/s]
#                    all         20         20      0.893      0.896       0.96      0.885
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      1.84G     0.3874     0.3859     0.8722         58        416: 100%|██████████| 5/5 [00:00<00:00, 10.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 24.79it/s]
#                    all         20         20      0.896        0.9      0.938      0.874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      1.84G     0.3829     0.4053      0.867         65        416: 100%|██████████| 5/5 [00:00<00:00, 11.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 24.73it/s]
#                    all         20         20      0.877        0.9      0.938      0.847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      1.84G     0.3855     0.4142     0.8652         56        416: 100%|██████████| 5/5 [00:00<00:00, 10.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.25it/s]
#                    all         20         20      0.859      0.945      0.977      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      1.84G     0.3629     0.3805     0.8525         58        416: 100%|██████████| 5/5 [00:00<00:00, 11.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.66it/s]
#                    all         20         20      0.859      0.943      0.986      0.902
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      1.84G     0.4128     0.4194     0.8741         63        416: 100%|██████████| 5/5 [00:00<00:00, 10.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 27.05it/s]
#                    all         20         20      0.887      0.939       0.99      0.933
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      1.84G      0.395      0.404     0.8643         55        416: 100%|██████████| 5/5 [00:00<00:00, 11.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.56it/s]
#                    all         20         20       0.86      0.977      0.995      0.939
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      1.84G     0.3701     0.3667     0.8675         58        416: 100%|██████████| 5/5 [00:00<00:00, 11.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 26.03it/s]
#                    all         20         20      0.862          1      0.995      0.921
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      1.84G     0.3158     0.3485     0.8132         31        416: 100%|██████████| 5/5 [00:03<00:00,  1.40it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 13.96it/s]
#                    all         20         20       0.87          1      0.995      0.911
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      1.84G     0.3245     0.3378     0.8117         31        416: 100%|██████████| 5/5 [00:01<00:00,  3.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 25.68it/s]
#                    all         20         20      0.906      0.998      0.995      0.921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      1.84G     0.3149     0.3093     0.7931         31        416: 100%|██████████| 5/5 [00:00<00:00,  9.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 14.00it/s]
#                    all         20         20      0.988          1      0.995      0.923
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      1.84G     0.2907     0.3116     0.8104         31        416: 100%|██████████| 5/5 [00:01<00:00,  3.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 13.68it/s]
#                    all         20         20      0.993          1      0.995      0.901
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      1.84G     0.3051     0.3064     0.8127         31        416: 100%|██████████| 5/5 [00:00<00:00,  9.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 16.58it/s]
#                    all         20         20      0.993          1      0.995      0.915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      1.84G     0.3029     0.3068     0.8243         31        416: 100%|██████████| 5/5 [00:00<00:00,  7.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 24.73it/s]
#                    all         20         20      0.991          1      0.995      0.937
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      1.84G     0.2996     0.3254     0.7836         31        416: 100%|██████████| 5/5 [00:00<00:00,  9.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 13.12it/s]
#                    all         20         20      0.989          1      0.995      0.955
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      1.84G     0.3012     0.2796     0.8115         31        416: 100%|██████████| 5/5 [00:00<00:00,  9.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 13.62it/s]
#                    all         20         20      0.985          1      0.995      0.947
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      1.84G     0.3069     0.2893     0.8189         31        416: 100%|██████████| 5/5 [00:00<00:00, 10.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 25.83it/s]
#                    all         20         20      0.983      0.997      0.995      0.942
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      1.84G     0.2889     0.3009      0.803         31        416: 100%|██████████| 5/5 [00:00<00:00, 10.28it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 14.21it/s]
#                    all         20         20      0.971      0.989      0.995      0.927
#
# 100 epochs completed in 0.021 hours.
# Optimizer stripped from runs/detect/train3/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train3/weights/best.pt, 6.2MB
#
# Validating runs/detect/train3/weights/best.pt...
# Ultralytics YOLOv8.0.172 🚀 Python-3.10.12 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 4080 Laptop GPU, 12010MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 31.64it/s]
#                    all         20         20      0.989          1      0.995      0.955
#                    bad         20         10       0.98          1      0.995      0.983
#                   good         20         10      0.999          1      0.995      0.927
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 0.2ms postprocess per image
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7f0740141720>
# fitness: 0.9589062415119242
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([     0.9831,     0.92669])
# names: {0: 'bad', 1: 'good'}
# plot: False
# results_dict: {'metrics/precision(B)': 0.9894232352579517, 'metrics/recall(B)': 1.0, 'metrics/mAP50(B)': 0.995, 'metrics/mAP50-95(B)': 0.9548958239021379, 'fitness': 0.9589062415119242}
# save_dir: PosixPath('runs/detect/train3')
# speed: {'preprocess': 0.06121397018432617, 'inference': 0.5631804466247559, 'loss': 0.0002741813659667969, 'postprocess': 0.19423961639404297}

# %%
results = model.predict(source='./dataset/test/images/', save=True)
# Out:
# image 1/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_F_B_14.jpg: 416x416 1 good, 2.2ms
# image 2/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_F_B_18.jpg: 416x416 1 bad, 2.2ms
# image 3/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_F_B_25.jpg: 416x416 1 bad, 3.4ms
# image 4/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_F_B_26.jpg: 416x416 1 bad, 3.3ms
# image 5/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_F_B_46.jpg: 416x416 1 bad, 2.2ms
# image 6/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_F_W_50.jpg: 416x416 1 bad, 2.2ms
# image 7/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_F_W_54.jpg: 416x416 1 bad, 2.2ms
# image 8/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_F_W_73.jpg: 416x416 1 bad, 2.1ms
# image 9/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_F_W_83.jpg: 416x416 1 bad, 2.2ms
# image 10/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_F_W_94.jpg: 416x416 1 bad, 2.2ms
# image 11/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_T_B_14.jpg: 416x416 1 good, 2.2ms
# image 12/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_T_B_18.jpg: 416x416 1 good, 2.2ms
# image 13/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_T_B_25.jpg: 416x416 1 bad, 2.1ms
# image 14/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_T_B_26.jpg: 416x416 1 bad, 1 good, 2.1ms
# image 15/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_T_B_46.jpg: 416x416 1 bad, 2.2ms
# image 16/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_T_W_50.jpg: 416x416 1 good, 2.1ms
# image 17/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_T_W_54.jpg: 416x416 1 good, 2.2ms
# image 18/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_T_W_73.jpg: 416x416 1 good, 2.2ms
# image 19/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_T_W_83.jpg: 416x416 1 good, 2.2ms
# image 20/20 /home/seokhwan/workspace/fabr/dataset/test/images/Button_T_W_94.jpg: 416x416 1 good, 2.1ms
# Speed: 1.1ms preprocess, 2.3ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/predict
